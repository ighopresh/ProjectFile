# %% [markdown]
# <a href="https://colab.research.google.com/github/ighopresh/ProjectFile/blob/main/Implementation_SIMDProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Libraries and Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### File Paths for Data Import

# %%
female_under_16_path = r"C:\Users\Ace\Documents\side projects\raw data\Female populations for under 16 , 2001 - 2020.csv"
female_working_age_group_path = r"C:\Users\Ace\Documents\side projects\raw data\Female working age group, 2001 - 2021.csv"
female_pensionable_age_group_path = r"C:\Users\Ace\Documents\side projects\raw data\Female Pensionable Age, 2001 - 2021.csv"
male_under_16_path = r"C:\Users\Ace\Documents\side projects\raw data\Total Male population under 16, 2001 - 2021.csv"
male_working_age_group_path = r"C:\Users\Ace\Documents\side projects\raw data\Male working age group, 2001 - 2021.csv"
male_pensionable_age_group_path = r"C:\Users\Ace\Documents\side projects\raw data\Male Pensionable age, 2001 - 2021.csv"
total_under_16_path = r"C:\Users\Ace\Documents\side projects\raw data\Total population under 16, 2001 - 2021.csv"
total_working_age_group_path = r"C:\Users\Ace\Documents\side projects\raw data\total population for working age group, 2001 - 2021.csv"
total_pensionable_age_group_path = r"C:\Users\Ace\Documents\side projects\raw data\Total population for Pensionable age - 2001 - 2021.csv"
year_2020_data_path = r"C:\Users\Ace\Documents\side projects\raw data\Year 2020 data, in the three age divisions.csv"
SIMD_2020_data_path = r"C:\Users\Ace\Documents\side projects\raw data\SIMD+2020v2+-+indicators (3).xlsx"

# %% [markdown]
# ### Data Loading and DataFrame Creation for Population Statistics.

# %%
female_under_16_df = pd.read_csv(female_under_16_path, na_values=' ', index_col=0, nrows=33)  #Population Estimates Summary by Current Geographic Boundaries for Females under the age of 16 (Under 16)
female_working_age_group_df = pd.read_csv(female_working_age_group_path, na_values=' ', index_col=0, nrows=33) #Population Estimates Summary (Current Geographic Boundaries) Females working group (16 - 64)
female_pensionable_age_group_df = pd.read_csv(female_pensionable_age_group_path, na_values=' ', index_col=0, nrows=33) #Population Estimates Summary (Current Geographic Boundaries) Females pension group (65 and above)
male_under_16_df = pd.read_csv(male_under_16_path, na_values=' ', index_col=0, nrows=33) #Population Estimates Summary by Current Geographic Boundaries for Males under the age of 16 (Under 16)
male_working_age_group_df = pd.read_csv(male_working_age_group_path, na_values=' ', index_col=0, nrows=33) #Population Estimates Summary (Current Geographic Boundaries) Males working group (16 - 64)
male_pensionable_age_group_df = pd.read_csv(male_pensionable_age_group_path, na_values=' ', index_col=0, nrows=33) #Population Estimates Summary (Current Geographic Boundaries) Males pension group (65 and above)
total_under_16_df = pd.read_csv(total_under_16_path, na_values=' ', index_col=0, nrows=33)
total_working_age_group_df = pd.read_csv(total_working_age_group_path, na_values=' ', index_col=0, nrows=33)
total_pensionable_age_group_df = pd.read_csv(total_pensionable_age_group_path, na_values=' ', index_col=0, nrows=33)
year_2020_data_df = pd.read_csv(year_2020_data_path)
SIMD_2020_data_df = pd.read_excel(SIMD_2020_data_path)

# %% [markdown]
# ### Heatmap for population statistics for all age cohorts

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

sns.heatmap(female_under_16_df.iloc[1:33, :], cmap='Blues', linewidths=0.5, linecolor='gray', cbar=False, ax=axes[0])
axes[0].set_title('Females(Under 16)')
axes[0].set_xlabel('X-axis Label')
axes[0].set_ylabel('Y-axis Label')

sns.heatmap(female_working_age_group_df.iloc[1:33, :], cmap='Blues', linewidths=0.5, linecolor='gray', cbar=False, ax=axes[1])
axes[1].set_title('Females (16-64)')
axes[1].set_xlabel('X-axis Label')
axes[1].set_ylabel('Y-axis Label')

sns.heatmap(female_pensionable_age_group_df.iloc[1:33, :], cmap='Blues', linewidths=0.5, linecolor='gray', cbar_ax=fig.add_axes([0.93, 0.15, 0.02, 0.7]), ax=axes[2])
axes[2].set_title('Females (65 and above)')
axes[2].set_xlabel('X-axis Label')
axes[2].set_ylabel('Y-axis Label')

plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

sns.heatmap(male_under_16_df.iloc[1:33, :], cmap='Blues', linewidths=0.5, linecolor='gray', cbar=False, ax=axes[0])
axes[0].set_title('Males(Under 16)')
axes[0].set_xlabel('X-axis Label')
axes[0].set_ylabel('Y-axis Label')

sns.heatmap(male_working_age_group_df.iloc[1:33, :], cmap='Blues', linewidths=0.5, linecolor='gray', cbar=False, ax=axes[1])
axes[1].set_title('Males (16-64)')
axes[1].set_xlabel('X-axis Label')
axes[1].set_ylabel('Y-axis Label')

sns.heatmap(male_pensionable_age_group_df.iloc[1:33, :], cmap='Blues', linewidths=0.5, linecolor='gray', cbar_ax=fig.add_axes([0.93, 0.15, 0.02, 0.7]), ax=axes[2])
axes[2].set_title('Males (65 and above)')
axes[2].set_xlabel('X-axis Label')
axes[2].set_ylabel('Y-axis Label')


# plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

sns.heatmap(total_under_16_df.iloc[1:33, :], cmap='Blues', linewidths=0.5, linecolor='gray', cbar=False, ax=axes[0])
axes[0].set_title('Total(Under 16)')
axes[0].set_xlabel('X-axis Label')
axes[0].set_ylabel('Y-axis Label')

sns.heatmap(total_working_age_group_df.iloc[1:33, :], cmap='Blues', linewidths=0.5, linecolor='gray', cbar=False, ax=axes[1])
axes[1].set_title('Total (16-64)')
axes[1].set_xlabel('X-axis Label')
axes[1].set_ylabel('Y-axis Label')

sns.heatmap(total_pensionable_age_group_df.iloc[1:33, :], cmap='Blues', linewidths=0.5, linecolor='gray', cbar_ax=fig.add_axes([0.93, 0.15, 0.02, 0.7]), ax=axes[2])
axes[2].set_title('Total (65 and above)')
axes[2].set_xlabel('X-axis Label')
axes[2].set_ylabel('Y-axis Label')



plt.show()

# %% [markdown]
# ### Raw data heatmap

# %%
total_working_age_raw_df = pd.read_csv(total_working_age_group_path, na_values=' ', index_col=0)
total_pension_raw_df = pd.read_csv(total_pensionable_age_group_path, na_values=' ', index_col=0)
total_under_16_raw_df = pd.read_csv(total_under_16_path, na_values=' ', index_col=0)
male_working_age_df = pd.read_csv(male_working_age_group_path, na_values=' ', index_col=0)
male_pension_raw_df = pd.read_csv(male_pensionable_age_group_path, na_values=' ', index_col=0)
male_under_16_raw_df = pd.read_csv(male_under_16_path, na_values=' ', index_col=0)
female_working_age_raw_df = pd.read_csv(female_working_age_group_path, na_values=' ', index_col=0)
female_pension_raw_df = pd.read_csv(female_pensionable_age_group_path, na_values=' ', index_col=0)
female_under_16_raw_df = pd.read_csv(female_under_16_path, na_values=' ', index_col=0)

# %%
data_list = [total_working_age_raw_df, total_pension_raw_df, total_under_16_raw_df, male_working_age_df, male_pension_raw_df, male_under_16_raw_df, female_working_age_raw_df,
female_pension_raw_df, female_under_16_raw_df]

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(12, 12))

axes = axes.flatten()

titles = ['Heatmap 1', 'Heatmap 2', 'Heatmap 3', 'Heatmap 4', 'Heatmap 5', 'Heatmap 6', 'Heatmap 7', 'Heatmap 8', 'Heatmap 9']

for i, ax in enumerate(axes):
    sns.heatmap(data_list[i], ax=ax, cmap='Reds', cbar=False)
    ax.set_title(titles[i])

plt.tight_layout()

plt.show()
